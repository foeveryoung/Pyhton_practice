# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot([3,1,4,5,2]) #只有一个输入列表数组时，参数被当作Y轴，X轴以索引自动生成
plt.ylabel('Grade')
#plt.savefig('C:\',dpi=600)   #将输出图像存储为文件，默认格式PNG格式，可以通过dpi修改输出质量
plt.show()

# %%
plt.plot([0,2,4,6,8],[3,1,4,5,2])
plt.axis([-1,10,0,6])
plt.show()

# %%
a1=np.arange(10)
plt.plot(a1,a1*1.5,'go-',a1,a1*2.5,'rx',a1,a1*3.5,'*',a1,a1*4.5,'b-.')
plt.show()

# %% [markdown]
# ### subplot

# %%
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
a=np.arange(0,5,0.02)
plt.subplot(221)
plt.plot(a,f(a))
plt.subplot(222)
plt.plot(a,np.cos(2*np.pi*f(a)),'r--')
plt.show()

# %% [markdown]
# ### 中文显示

# %%
import matplotlib
matplotlib.rcParams['font.family']='SimHei' 
#font.family 用于显示字体名字
#font.style 字体风格 正常'normal'或斜体italic
#font.size 字体大小 证书字号或者'large' 'x-small'
#中文字体的种类  SimHei黑体 Kaiti楷体 LiSu隶书 FangSong仿宋 YouYuan幼圆 STSong华文宋体
plt.plot([3,1,4,5,2])
plt.ylabel("纵轴")
plt.show()

# %%
a3=np.arange(0,5,0.02)
plt.xlabel('横轴',fontproperties='SimHei',fontsize=20)
plt.ylabel('纵轴',fontproperties='SimHei',fontsize=20)
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.show()

# %% [markdown]
# ### 文本显示函数

# %%
a4=np.arange(0,5,0.02)
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.xlabel('横轴',fontproperties='SimHei',fontsize=15,color='green')
plt.ylabel('纵轴',fontproperties='SimHei',fontsize=15,color='red')
plt.title('正弦实例',fontproperties='SimHei',fontsize=25)
plt.text(2,1,'mu=100',fontsize=15) #plt.annotate 在图像中增加带箭头的注解
plt.axis([-1,6,-2,2])
plt.grid(True)
plt.show()

# %%
ax1=plt.subplot2grid((3,3),(0,0),colspan=3)
ax2=plt.subplot2grid((3,3),(1,0),colspan=2)
ax3=plt.subplot2grid((3,3),(2,0))
ax4=plt.subplot2grid((3,3),(2,1))
ax5=plt.subplot2grid((3,3),(1,2),rowspan=2)

# %% [markdown]
# ### 饼图

# %%
labels=['Frogs','Hogs','Dogs','Logs']
sizes=[15,30,20,35]
explode=(0,0.1,0,0)
plt.pie(sizes,explode=explode,labels=labels,autopct='%1.1f%%',shadow=False,startangle=90)
#plt.axis('equal') 正圆
plt.show()

# %% [markdown]
# ### 直方图

# %%
mu,sigma=100,20
a=np.random.normal(mu,sigma,size=100)
plt.hist(a,20,normed=0,histtype='stepfilled',facecolor='b',alpha=0.75)
#20表示20个条状，normed=0为个数，=1为密度
plt.title('Histogram')
plt.show()
# Out:
# D:\mathwork\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### 极坐标

# %%
N=20
theta=np.linspace(0,2*np.pi,N,endpoint=False)
radii=10*np.random.rand(N)
width=np.pi/4*np.random.rand(N)

ax=plt.subplot(111,projection='polar')
bars=ax.bar(theta,radii,width=width,bottom=0)
#           left  height width
for r,bar in zip(radii,bars):
    bar.set_facecolor(plt.cm.viridis(r/10))
    bar.set_alpha(0.5)
    
plt.show()

# %% [markdown]
# ### 散点图

# %%
fig,ax=plt.subplots()
ax.plot(10*np.random.randn(100),10*np.random.randn(100),'o')
ax.set_title('Simple Scatter')
plt.show()
